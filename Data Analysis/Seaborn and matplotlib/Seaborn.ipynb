# %% [markdown]
# # Seaborn - Statistical data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

d=pd.read_csv('train-Copy1.csv')

# %% [markdown]
# ## Relational plots - used to perform multivariant analysis
# - scatter plot
# - line plot
# - facetgrids

# %% [markdown]
# # `scatter plot`

# %%
#plt.style.use('fivethirtyeight')

# %%
da=sns.load_dataset('tips') #inbuilt dataset comes from seaborn library - tips
da
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#ploting
sns.relplot(x='total_bill',y='tip',kind='scatter',data=da) #default kind='scatter'

# %%
sns.relplot(x='total_bill',y='tip',kind='line',data=da)

# %% [markdown]
# ## hue ,size, style parameters

# %%
#hue parameter, lets find gender of the each person (or point in the graph) usind sex column
sns.relplot(x='total_bill',y='tip',hue='sex',data=da)

# %%
#style parameter. lets day if we want to find the person is smoker or not in the above graph
sns.relplot(x='total_bill',y='tip',hue='sex',style='smoker',data=da)

# %%
#size parameter - only on numerical data, will apply this size parameter for the above grraph
sns.relplot(x='total_bill',y='tip',hue='sex',style='smoker',size='size',sizes=(2,100),data=da)

# %%
# scatterplot also gives the same output as above
sns.scatterplot(x='total_bill',y='tip',hue='sex',style='smoker',size='size',sizes=(20,200),data=da)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#facetgrid, this used to plot against time on the x axis
g=sns.FacetGrid(da,col='time')
g.map(plt.hist, "tip")

# %% [markdown]
# # plotting with categorical data
# ## `catplot - figure level function`
# ### 1.Categorical scatterplots -stripplot, swarmplot
# ### 2.Categorical distributionplots -boxplot, voilineplot
# ### 3.Categorical estimate plots - pointplot, barplot, countplot
# ### 4.Categorical categorical plots - heatmaps, clustermaps
# ### 5.Ploting side by side graphs using facetgrida

# %% [markdown]
# # 1.Categorical scatterplots
# - X axis -> categorical  data
# - Y axis -> numerical data

# %%
#strip plot
sns.catplot(x='day',y='tip',kind='strip',data=da)

"""jitter - which induses the noise becouse of which the valuses are scattered a little, according to the days, if we 
make the jitter parameter equal to zerro you can see the values without any noise, but all prefer to use the below grap
as it is now"""
# Out:
# 'jitter - which induses the noise becouse of which the valuses are scattered a little, according to the days, if we \nmake the jitter parameter equal to zerro you can see the values without any noise, but all prefer to use the below grap\nas it is now'

# %%
#jitter=0
sns.catplot(x='day',y='tip',kind='strip',jitter=0,data=da)

# %%
# we can use hue (only hue) parameter in categorical plot
sns.catplot(x='day',y='tip',kind='strip',hue='sex',data=da)

# %%
#Swarm plot
sns.catplot(x='day',y='tip',kind='swarm',data=da)
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# we can use hue (only hue) parameter in categorical plot
sns.catplot(x='day',y='tip',kind='swarm',hue='sex',data=da)
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplot
# -The image below is a boxplot. A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.![1_2c21SkzJMf3frPXPAR_gZA.png](attachment:1_2c21SkzJMf3frPXPAR_gZA.png)

# %%
#using numericalata - univariant 

sns.boxplot(da['total_bill'])
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
#using catplot
sns.catplot(x='day',y='total_bill',kind='box',hue='sex',data=da)

# %% [markdown]
# ## Violine plots
# * It is a method of ploting numeric data and can be considered a combination of the box plot with probability density plot.
# * It is often used to compare the distribution of a given variable across some categories

# %%
#numerical variable - tip

plt.figure(figsize=(8,6))
sns.violinplot(da['total_bill'])
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
#violine plot using cat plot
sns.catplot(x='day',y='total_bill',kind='violin',data=da)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=da,hue='sex')

# %%
#to use the space efficently we can use split to print both male and female in one violin
sns.catplot(x='day',y='total_bill',kind='violin',data=da,hue='sex',split=True)

# %% [markdown]
# # Barplots and count plots

# %%
#want to find mean value of total_bill agains smoker
sns.catplot(x='smoker',y='total_bill',kind='bar',data=da)

# %%
sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',data=da)

# %% [markdown]
# ### box plot alwasys esimmates the mean value if  you want to change that, like want to ge output as median you can use estimator parameter and call any function,

# %% [markdown]
# import numpy as np
# sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',estimator=np.median,data=da)

# %%
# similarlly for variance
sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',estimator=np.var,data=da)

# %% [markdown]
# # countplot

# %%
sns.catplot(x='sex',hue='smoker',kind='count',data=da)

# %% [markdown]
# # Heatmaps
# ### Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# create a pivot table using flights table
pt=flights.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')
pt
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pt, annot=True, fmt='d')
# annot give the value inside each bar, and fmt='d' gives the interger
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
#to remove the side bar cbar=False and to give a gap between each bar linewidth=0.5
plt.figure(figsize=(10,6))
sns.heatmap(pt, cbar=False,linewidth=0.4)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# # Cluster map
# Coming to the heat map, it is a graphical representation of data where values are represented using colors. Variation in the intensity of color depicts how data is clustered or varies over space.
#
# The clustermap() function of seaborn plots a hierarchically-clustered heat map of the given matrix dataset. It returns a clustered grid index.

# %%
# the clustering happens based on the metrics parameter and defaulit is said to be euclidean.
# the euclidean distance between two points, based on this the default clusterng happens you can change this using metrics patameter

sns.clustermap(pt)

# %%
# metric='correlation' and clusterning only using column
sns.clustermap(pt,metric='correlation', annot=True, fmt='d', row_cluster=False)
plt.show()

# %% [markdown]
# # Joint plot
# #### Joint plot created multi panel figure the shows both the bivariant ( or joint ) relationship between two variables along with the univariant (or marginal) distribution of each on separate axes.
# - we can use joint plot in the 4 ways
# 1. scater  plot
# 2. hexbin plot
# 3. kde plot
# 4. regplot

# %%
da.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill',y='tip',data=da)

# %%
#hex plot
sns.jointplot(x='total_bill',y='tip',kind='hex',data=da)

# %%
# 2d kde plot
sns.jointplot(x='total_bill',y='tip',kind='kde',data=da)

# %%
# regression plot
sns.jointplot(x='total_bill',y='tip',kind='reg',data=da)

# %% [markdown]
# # Pairplot
# ### pair plots are used to plot multiple pair wise bivariant distribution in a dataset, this creates a matix of axes and shows the relationship for each pair of columns in a dataframe, it also draws the univariant distribution of each variable on the diogonal axes.

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ## Distplots - distribution plots
# ####  Distplot combines 3 things on each graph
# - 1.histogram
# - 2.kernal density estimation  (pdf)
# - 3.rugplot

# %%
t=sns.load_dataset('titanic')
t.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 575         0       3    male  19.0      0      0  14.5000        S   Third
# 580         1       2  female  25.0      1      1  30.0000        S  Second
# 23          1       1    male  28.0      0      0  35.5000        S   First
# 174         0       1    male  56.0      0      0  30.6958        C   First
# 878         0       3    male   NaN      0      0   7.8958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 575    man        True  NaN  Southampton    no   True
# 580  woman       False  NaN  Southampton   yes  False
# 23     man        True    A  Southampton   yes   True
# 174    man        True    A    Cherbourg    no   True
# 878    man        True  NaN  Southampton    no   True

# %%
# will fill missing values int age column with mean value
t['age'].fillna(t['age'].mean(), inplace=True)

# %%
t.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 146         1       3    male  27.0      0      0   7.7958        S  Third
# 130         0       3    male  33.0      0      0   7.8958        C  Third
# 25          1       3  female  38.0      1      5  31.3875        S  Third
# 189         0       3    male  36.0      0      0   7.8958        S  Third
# 352         0       3    male  15.0      1      1   7.2292        C  Third
#
#        who  adult_male deck  embark_town alive  alone
# 146    man        True  NaN  Southampton   yes   True
# 130    man        True  NaN    Cherbourg    no   True
# 25   woman       False  NaN  Southampton   yes  False
# 189    man        True  NaN  Southampton    no   True
# 352  child       False  NaN    Cherbourg    no  False

# %%
# Distplot
sns.distplot(t['age'])
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(t['age'], kde=False, bins=100)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# only kde
sns.distplot(t['age'],hist=False)
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#rug plot
sns.distplot(t['age'], hist=False, kde=False, rug=True)
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>

# %%
# age didtribution where the passangers are survived
plt.figure(figsize=(10,6))
sns.distplot(t[t['survived']==1]['age'])
sns.distplot(t[t['survived']==0]['age'])
# Out:
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\darsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>
